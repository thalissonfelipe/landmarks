# %% [markdown]
# # Quantidade/região de pontos próximo ao olho direito
#
# Nuvem: bs000_E_ANGER_0.pcd
#
# ## Raio 10
#
# - Quantidade de pontos: 408
#
# ![image-50.png](attachment:image-50.png)
#
# ![image-31.png](attachment:image-31.png)
#
# ![image-32.png](attachment:image-32.png)
#
# ![image-33.png](attachment:image-33.png)
#
# ## Raio 11
#
# - Quantidade de pontos: 485
#
# ![image-2.png](attachment:image-2.png)
#
# ## Raio 12
#
# - Quantidade de pontos: 566
#
# ![image-3.png](attachment:image-3.png)
#
# ## Raio 13
#
# - Quantidade de pontos: 656
#
# ![image-4.png](attachment:image-4.png)
#
# ## Raio 14
#
# - Quantidade de pontos: 746
#
# ![image-5.png](attachment:image-5.png)
#
# ## Raio 15
#
# - Quantidade de pontos: 838
#
# ![image-49.png](attachment:image-49.png)
#
# ![image-34.png](attachment:image-34.png)
#
# ![image-35.png](attachment:image-35.png)
#
# ![image-36.png](attachment:image-36.png)
#
# ![image-54.png](attachment:image-54.png)
#
# ## Raio 20
#
# - Quantidade de pontos: 1485
#
# ![image-48.png](attachment:image-48.png)
#
# ![image-37.png](attachment:image-37.png)
#
# ![image-38.png](attachment:image-38.png)
#
# ![image-39.png](attachment:image-39.png)
#
# ![image-51.png](attachment:image-51.png)
#
# ## Raio 25
#
# - Quantidade de pontos: 2656
#
# ![image-46.png](attachment:image-46.png)
#
# ![image-40.png](attachment:image-40.png)
#
# ![image-41.png](attachment:image-41.png)
#
# ![image-42.png](attachment:image-42.png)
#
# ![image-52.png](attachment:image-52.png)
#
# ## Raio 30
#
# - Quantidade de pontos: 4215
#
# ![image-47.png](attachment:image-47.png)
#
# ![image-43.png](attachment:image-43.png)
#
# ![image-44.png](attachment:image-44.png)
#
# ![image-45.png](attachment:image-45.png)
#
# ![image-53.png](attachment:image-53.png)
#
# ## Raio 40
#
# - Quantidade de pontos: 8100
#
# ![image-8.png](attachment:image-8.png)
#
# ## Raio 50
#
# - Quantidade de pontos: 13206
#
# ![image-9.png](attachment:image-9.png)
#
# ## Raio 60
#
# - Quantidade de pontos: 13206
#
# ![image-10.png](attachment:image-10.png)
#
#
# # Descritores da Matriz de Covariância calculados em objetos:
#
# ## Cubo
#
# Número de pontos: 10000
#
# - Sum: 1.003810
# - Omnivariance: 1.000000
# - Eigenentropy: 1.098809
# - Anisotropy: 0.043222
# - Planarity: 0.013304
# - Linearity: 0.029918
# - Surface Variation: 0.326896
# - Sphericity: 0.956778
# - Verticality: 0.349865
#
# ![image-11.png](attachment:image-11.png)
#
# ## Esfera
#
# Número de pontos: 2092
#
# - Sum: 1.039243
# - Omnivariance: 1.000000
# - Eigenentropy: 1.101173
# - Anisotropy: 0.076152
# - Planarity: 0.031829
# - Linearity: 0.044323
# - Surface Variation: 0.320834
# - Sphericity: 0.923848
# - Verticality: 0.281676
#
# ![image-12.png](attachment:image-12.png)
#
# ## Cilindro
#
# Número de pontos: 9417
#
# - Sum: 1.002595
# - Omnivariance: 1.000000
# - Eigenentropy: 1.088134
# - Anisotropy: 0.303341
# - Planarity: 0.176912
# - Linearity: 0.126429
# - Surface Variation: 0.271049
# - Sphericity: 0.696659
# - Verticality: 0.920368
#
# ![image-13.png](attachment:image-13.png)
#
# ## Cilindro 2
#
# Número de pontos: 23643
#
# - Sum: 1.066022
# - Omnivariance: 1.000000
# - Eigenentropy: 1.101857
# - Anisotropy: 0.103565
# - Planarity: 0.076993
# - Linearity: 0.026572
# - Surface Variation: 0.312362
# - Sphericity: 0.896435
# - Verticality: 0.010434
#
# ![image-14.png](attachment:image-14.png)
#
# ## Plano
#
# Número de pontos: 10000
#
# - Sum: 0.672564
# - Omnivariance: 1.000000
# - Eigenentropy: -nan
# - Anisotropy: 1.000000
# - Planarity: 0.964145
# - Linearity: 0.035855
# - Surface Variation: 0.000000
# - Sphericity: 0.000000
# - Verticality: 0.000000
#
# ![image-15.png](attachment:image-15.png)
